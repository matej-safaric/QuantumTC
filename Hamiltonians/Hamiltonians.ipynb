# %%
from qiskit.quantum_info import Operator, Statevector
from Libraries import HamiltonianEvolution as HE
from numpy import sqrt

X = Operator([[0, 1], [1, 0]])
Y = Operator([[0, -1.0j], [1.0j, 0]])
Z = Operator([[1, 0], [0, -1]])
H = Operator([[1 / sqrt(2), 1 / sqrt(2)], [1 / sqrt(2), -1 / sqrt(2)]])
S = Operator([[1, 0], [0, 1.0j]])
T = Operator([[1, 0], [0, (1 + 1.0j) / sqrt(2)]])

# %% [markdown]
# # Hadamard gate ($H$-gate)

# %%
v = Statevector.from_label('0')
Ham = HE.hamiltonian(H, 1)

HE.plotEvolution(Ham, v, 2, 0.01)

# %%
HE.plotPhaseEvolution(Ham, v, 2, 0.01)

# %% [markdown]
# # $Y$-gate

# %%
Ham = HE.hamiltonian(Y, 1)
HE.plotEvolution(Ham, v, 2, 0.01)

# %%
HE.plotPhaseEvolution(Ham, v, 2, 0.01)

# %% [markdown]
# # $S$-gate

# %%
Ham = HE.hamiltonian(S, 1)
print(Ham)

v = Statevector.from_label('1')
HE.plotEvolution(Ham, v, 2, 0.01)
# Out:
# [[ 0.        +0.j  0.        -0.j]
#  [ 0.        +0.j -1.57079633+0.j]]

# %%
HE.plotPhaseEvolution(Ham, v, 2, 0.01)

# %%
v = Statevector.from_label('-')
HE.plotEvolution(Ham, v, 2, 0.01)

# %%
HE.plotPhaseEvolution(Ham, v, 2, 0.01)

# %% [markdown]
# # FDTD-appropriate Hamiltonians

# %%
from Libraries import HamiltonianEvolution as HE
